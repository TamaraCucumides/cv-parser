# %% [markdown]
# # Demo 22-9-2020

# %%
import matplotlib.pyplot as plt
import json
from wordcloud import WordCloud 
from collections import Counter


def show_words(file):
    with open(file, "r") as read_file:
        cv_txt = json.load(read_file)
    for key in cv_txt.keys():
        if cv_txt[key] is None:
            cv_txt[key] = []
    list_words = cv_txt['Palabras Claves']*2 + cv_txt["Licencias-Certificaciones"]*5  + cv_txt["Lenguajes"]*2 + cv_txt["Skills"]*10 + cv_txt["Educacion"]["Grado_mas_alto"]*4
    word_could_dict=Counter(list_words)
    wordcloud = WordCloud(background_color='white',width = 500, height = 250, max_words= 50).generate_from_frequencies(word_could_dict)
    plt.figure(figsize=(10,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    plt.close()

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1566746473048-Patricio_Mendez-CV.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": null,
#         "Correo": [
#             "patricioabelmc@hotmail.com"
#         ],
#         "Celular": "+56978971888",
#         "Linkedin": "www.linkedin.com/in/patriciomendezcaneo/"
#     },
#     "Nombre archivo": "1566746473048-Patricio_Mendez-CV.pdf",
#     "Licencias-Certificaciones": [
#         "CLASE B",
#         "LICENCIA DE CONDUCIR"
#     ],
#     "Palabras Claves": [
#         "Adaptable",
#         "Responsabilidad",
#         "Modelamiento",
#         "Análisis"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad Católica del Norte"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1567633704251-CVJMHSep2.docx.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Javier Andrés Madrid ",
#         "Correo": "jmhengsol@gmail.com",
#         "Celular": "+56972128607",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1567633704251-CVJMHSep2.docx",
#     "Licencias-Certificaciones": [
#         "SERVICIO MILITAR"
#     ],
#     "Palabras Claves": [
#         "Análisis",
#         "Negociación",
#         "Gestión",
#         "Aprender"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad Andrés Bello"
#         ],
#         "Grado_mas_alto": [
#             "Postgrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1568134345809-CV_Janis_Niño.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Janis Andreina Niño ",
#         "Correo": [
#             "janisvasquez@gmail.com"
#         ],
#         "Celular": "+56930666539",
#         "Linkedin": "www.linkedin.com/in/janis-niño-5856b026/"
#     },
#     "Nombre archivo": "1568134345809-CV_Janis_Niño.pdf",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Liderar",
#         "Análisis",
#         "Responsabilidad",
#         "Motivación",
#         "Proactividad",
#         "Creativo",
#         "Liderazgo",
#         "Estrategia",
#         "Compromiso",
#         "Colaboración",
#         "Gestión"
#     ],
#     "Educacion": {
#         "Universidades:": [],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1568216685891-CLAUDIA_GUERRERO_MIRANDA.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Claudia Andrea Guerrero ",
#         "Correo": "clguerre@fen.uchile.cl",
#         "Celular": "+56961234969",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1568216685891-CLAUDIA_GUERRERO_MIRANDA.pdf",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Tolerancia",
#         "Análisis",
#         "Responsabilidad",
#         "Proactividad",
#         "Analizar",
#         "Estrategia",
#         "Aprender",
#         "Negociación",
#         "Gestión"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad de Chile"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1568336891024-CV_Romina_Gonzalez_M.docx.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Romina Andrea Gonzalez ",
#         "Correo": "romina1803@live.cl",
#         "Celular": "+56998806005",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1568336891024-CV_Romina_Gonzalez_M.docx",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Tolerancia",
#         "Adaptable",
#         "Responsabilidad",
#         "Proactividad",
#         "Aprender",
#         "Puntual",
#         "Negociación"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad de Antofagasta"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1568562793715-CURRICULUM__VITAE_Álvaro_Doñas_.doc.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": null,
#         "Correo": "Alvaro.adu@gmail.com",
#         "Celular": "+56223136421",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1568562793715-CURRICULUM__VITAE_Álvaro_Doñas_.doc",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": null,
#     "Educacion": {
#         "Universidades:": [
#             "Universidad Central de Chile"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1568671250564-2019_08_Professional_CV4GRADUATE.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Sebastian Chamas Ferretto ",
#         "Correo": [
#             "sifchamas@gmail.com"
#         ],
#         "Celular": "+56942317715",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1568671250564-2019_08_Professional_CV4GRADUATE.pdf",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Aprender",
#         "Disciplina",
#         "Responsabilidad",
#         "Modelamiento"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad de Chile"
#         ],
#         "Grado_mas_alto": [
#             "Postgrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés"
#     ],
# ...

# %%
file= '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1569428597717-CV_-_Christian_Droguett_1.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Christian Philip Droguett ",
#         "Correo": [
#             "ch.droguett.l@gmail.com"
#         ],
#         "Celular": "+56945418524",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1569428597717-CV_-_Christian_Droguett_1.pdf",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Liderar",
#         "Análisis",
#         "Voluntariado",
#         "Responsabilidad",
#         "Modelamiento",
#         "Proactividad",
#         "Analizar",
#         "Negociación",
#         "Gestión"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad de Chile",
#             "Universidad Nacional Andrés Bello",
#             "Universidad Católica de Chile"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés",
#         "Español"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1569848795502-Francisco_carcamo.docx.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": null,
#         "Correo": [
#             "FJCS15@gmail.com"
#         ],
#         "Celular": "984134496",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1569848795502-Francisco_carcamo.docx",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": null,
#     "Educacion": {
#         "Universidades:": [],
#         "Grado_mas_alto": [
#             "Enseñanza media"
#         ]
#     },
#     "Lenguajes": [],
#     "Experiencia": "antecedentes laborales take a wok julio/2014-octubre /2015 ayudante de cocina octubre/ 2015 junio/2016 asistente de jefe de local poul julio /2016-diciembre/2016 ayudante de cocina aveniu du bois enero/2017- abril/2017 ayudante de cocina mamma mia abril/2017- junio/2017 operario mamut julio/2017- marzo/2018 maestro de cocina johnny rockets marzo/2018- julio/2019 ayudante y maestro de cocina 13 de agosto del 2019 ",
#     "Resumen": "curriculum vitae ",
#     "Skills": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1570055926805-CV_Rodrigo_Ibarra_Leiva.pdf.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Rodrigo Andrés Ibarra ",
#         "Correo": [
#             "ibarrarod@gmail.com"
#         ],
#         "Celular": "993827257",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1570055926805-CV_Rodrigo_Ibarra_Leiva.pdf",
#     "Licencias-Certificaciones": [
#         "CLASE B",
#         "CLASE C"
#     ],
#     "Palabras Claves": [
#         "Análisis",
#         "Responsabilidad",
#         "Proactividad",
#         "Liderazgo",
#         "Negociación",
#         "Gestión"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad Católica del Norte"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1570139255153-CV_Meychan_Munoz_Kcomt_Ago_2019.docx.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Meychan Muñoz Kcomt ",
#         "Correo": "meychan@gmail.com",
#         "Celular": "+94021090222",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1570139255153-CV_Meychan_Munoz_Kcomt_Ago_2019.docx",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Analizar",
#         "Estrategia",
#         "Liderar",
#         "Modelamiento",
#         "Negociación",
#         "Colaboración",
#         "Análisis",
#         "Gestión",
#         "Responsabilidad",
#         "Motivación",
#         "Liderazgo"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad de Chile",
#             "Universidad Alberto Hurtado",
#             "Universidad Diego Portales"
#         ],
#         "Grado_mas_alto": [
#             "Postgrado"
#         ]
#     },
#     "Lenguajes": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1570826760177-Curriculum_11_Alejandro.doc.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "Alejandro Rodriguez Gonzalez ",
#         "Correo": [
#             "Alejandrosrodriguezg@gmail.com"
#         ],
#         "Celular": "+56942018097",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1570826760177-Curriculum_11_Alejandro.doc",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Liderar",
#         "Responsabilidad",
#         "Liderazgo",
#         "Negociación",
#         "Gestión"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Universidad Andrés Bello",
#             "Universidad de Tarapacá"
#         ],
#         "Grado_mas_alto": [
#             "Postgrado"
#         ]
#     },
#     "Lenguajes": [],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1571262515076-curriculum_david.doc.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": "David Eduardo Godoy ",
#         "Correo": [
#             "davidgodoycontreras87@gmail.com"
#         ],
#         "Celular": "+56937250948",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1571262515076-curriculum_david.doc",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Tolerancia",
#         "Comprometido",
#         "Motivación",
#         "Aprender"
#     ],
#     "Educacion": {
#         "Universidades:": [],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Alemán"
#     ],
# ...

# %%
file = '/home/erwin/Genoma/cv-parser/parser/Outputs/output_parser/1571191954402-CV_Javiera_Barrales_Liberona..docx.json'
cv_txt = open(file, "r").read()
print(cv_txt)
show_words(file)
# Out:
# {
#     "Contacto": {
#         "Nombre": null,
#         "Correo": [
#             "javiera.barrales@usach.cl"
#         ],
#         "Celular": "+56976278970",
#         "Linkedin": null
#     },
#     "Nombre archivo": "1571191954402-CV_Javiera_Barrales_Liberona..docx",
#     "Licencias-Certificaciones": [],
#     "Palabras Claves": [
#         "Análisis",
#         "Motivación",
#         "Responsabilidad",
#         "Proactividad",
#         "Creativo",
#         "Aprender",
#         "Negociación"
#     ],
#     "Educacion": {
#         "Universidades:": [
#             "Instituto Chileno Norteamericano",
#             "Universidad de Santiago de Chile"
#         ],
#         "Grado_mas_alto": [
#             "Pregrado"
#         ]
#     },
#     "Lenguajes": [
#         "Inglés",
#         "Alemán"
#     ],
# ...
